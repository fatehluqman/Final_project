# %%
# Initial imports
import pandas as pd
from path import Path
from sqlalchemy import create_engine
from config import db_password

# %%
# Load the cy_stats2.csv dataset with data as of 11/15/2021
csv_path = Path("cy_stats2.csv")
cy_stats_df = pd.read_csv(csv_path)
cy_stats_df
# Out:
#     Position   Season   Tm   Lg   G   W   L   W/L%    MOV   SOS  ...   eFG%  \
# 0          0  2021-22  GSW  NBA  13  11   2  0.846  13.23 -2.87  ...  0.554
# 1          0  2021-22  BRK  NBA  14  10   4  0.714   5.00 -1.53  ...  0.553
# 2          0  2021-22  WAS  NBA  12   9   3  0.750   4.92 -0.10  ...  0.523
# 3          0  2021-22  CHI  NBA  13   9   4  0.692   4.92  0.29  ...  0.519
# 4          0  2021-22  CLE  NBA  14   9   5  0.643   2.21  0.38  ...  0.522
# 5          0  2021-22  PHO  NBA  12   9   3  0.750   5.75 -2.29  ...  0.540
# 6          0  2021-22  DEN  NBA  13   9   4  0.692   5.77 -0.41  ...  0.529
# 7          0  2021-22  MIA  NBA  13   8   5  0.615   6.62  0.84  ...  0.524
# 8          0  2021-22  UTA  NBA  13   8   5  0.615   6.62 -0.07  ...  0.533
# 9          0  2021-22  PHI  NBA  14   8   6  0.571   4.14 -1.33  ...  0.547
# 10         0  2021-22  LAL  NBA  14   8   6  0.571  -1.57 -1.66  ...  0.529
# 11         0  2021-22  LAC  NBA  13   8   5  0.615   5.23 -0.03  ...  0.526
# 12         0  2021-22  CHO  NBA  15   8   7  0.533  -1.80  1.94  ...  0.520
# 13         0  2021-22  DAL  NBA  12   8   4  0.667  -1.58 -0.53  ...  0.510
# 14         0  2021-22  NYK  NBA  13   7   6  0.538   0.46 -0.88  ...  0.525
# 15         0  2021-22  TOR  NBA  14   7   7  0.500   1.14  0.77  ...  0.498
# 16         0  2021-22  BOS  NBA  13   6   7  0.462   0.69  0.50  ...  0.504
# 17         0  2021-22  MEM  NBA  13   6   7  0.462  -6.54  2.08  ...  0.498
# 18         0  2021-22  MIL  NBA  14   6   8  0.429  -1.93  0.56  ...  0.522
# 19         0  2021-22  IND  NBA  14   6   8  0.429   0.64  2.19  ...  0.543
# 20         0  2021-22  POR  NBA  14   6   8  0.429  -0.43  1.35  ...  0.528
# 21         0  2021-22  ATL  NBA  14   5   9  0.357  -2.64  2.03  ...  0.509
# 22         0  2021-22  OKC  NBA  12   5   7  0.417  -8.17  0.87  ...  0.474
# 23         0  2021-22  SAC  NBA  13   5   8  0.385  -0.69  0.22  ...  0.524
# 24         0  2021-22  MIN  NBA  12   4   8  0.333  -4.42 -1.30  ...  0.489
# 28  0.522  13.9  25.8   0.167     0.548    0.583      12.1      22.0
# 29  0.534  16.8  21.0   0.199     0.519    0.553      12.9      23.3
#
#     opp_FT/FGA
# 0        0.163
# 1        0.157
# 2        0.182
# 3        0.175
# 4        0.137
# 5        0.160
# 6        0.158
# 7        0.184
# 8        0.159
# 9        0.167
# 10       0.182
# 11       0.148
# 12       0.183
# 13       0.155
# 14       0.167
# 15       0.197
# 16       0.198
# 17       0.165
# 18       0.163
# 19       0.195
# 20       0.147
# 21       0.168
# 22       0.145
# 23       0.169
# 24       0.207
# 25       0.141
# 26       0.177
# 27       0.183
# 28       0.196
# 29       0.187
#
# [30 rows x 24 columns]

# %%
cy_stats_df = cy_stats_df.rename(columns={'W/L%': 'Win_pct', 'eFG%': 'eFG_pct','TS%': 'TS_pct', 'TOV%': 'TOV_pct', 'ORB%': 'ORB_pct' ,'FT/FGA': 'FT_FGA',
                                   'opp_eFG%': 'Opp_eFG_pct','opp_TS%': 'Opp_TS_pct', 'opp_TOV%': 'Opp_TOV_pct', 'opp_ORB%': 'Opp_ORB_pct', 'opp_FT/FGA': 'Opp_FT_FGA' })
cy_stats_df.head()
# Out:
#    Position   Season   Tm   Lg   G   W  L  Win_pct    MOV   SOS  ...  eFG_pct  \
# 0         0  2021-22  GSW  NBA  13  11  2    0.846  13.23 -2.87  ...    0.554
# 1         0  2021-22  BRK  NBA  14  10  4    0.714   5.00 -1.53  ...    0.553
# 2         0  2021-22  WAS  NBA  12   9  3    0.750   4.92 -0.10  ...    0.523
# 3         0  2021-22  CHI  NBA  13   9  4    0.692   4.92  0.29  ...    0.519
# 4         0  2021-22  CLE  NBA  14   9  5    0.643   2.21  0.38  ...    0.522
#
#    TS_pct  TOV_pct  ORB_pct  FT_FGA  Opp_eFG_pct  Opp_TS_pct  Opp_TOV_pct  \
# 0   0.585     13.8     23.0   0.182        0.497       0.527         14.7
# 1   0.586     14.1     16.5   0.188        0.484       0.516         11.3
# 2   0.560     12.9     20.1   0.191        0.476       0.516         11.1
# 3   0.562     12.1     20.4   0.204        0.508       0.543         14.7
# 4   0.555     14.9     23.7   0.182        0.500       0.528         13.7
#
#    Opp_ORB_pct  Opp_FT_FGA
# 0         17.9       0.163
# 1         22.0       0.157
# 2         21.4       0.182
# 3         21.8       0.175
# 4         26.4       0.137
#
# [5 rows x 24 columns]

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/nba_champs"

# %%
engine = create_engine(db_string)

# %%
cy_stats_df.to_sql(name='cy_stats2', con=engine)
