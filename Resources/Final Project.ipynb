# %%
# Initial imports
import pandas as pd
from path import Path

# %%
# Load the stats.csv dataset.
csv_path = Path("stats.csv")
stats_df = pd.read_csv(csv_path)
stats_df.head()
# Out:
#    Rk   Season    Tm   Lg   G   W   L   W/L%   MOV   SOS  ...   eFG%    TS%  \
# 0   1  2020-21  WAS*  NBA  72  34  38  0.472 -1.83 -0.01  ...  0.531  0.569
# 1   2  2020-21  UTA*  NBA  72  52  20  0.722  9.25 -0.29  ...  0.563  0.597
# 2   3  2020-21   TOR  NBA  72  27  45  0.375 -0.47 -0.07  ...  0.529  0.567
# 3   4  2020-21   SAS  NBA  72  33  39  0.458 -1.74  0.15  ...  0.517  0.554
# 4   5  2020-21   SAC  NBA  72  31  41  0.431 -3.68  0.23  ...  0.549  0.578
#
#    TOV%  ORB%  FT/FGA  opp_eFG%  opp_TS%  opp_TOV%  opp_ORB%  opp_FT/FGA
# 0  12.3  21.3   0.221     0.539    0.576      12.5      22.4       0.217
# 1  12.7  24.5   0.195     0.507    0.537      10.3      20.7       0.159
# 2  11.9  20.8   0.196     0.543    0.584      14.4      23.7       0.234
# 3  10.2  20.0   0.192     0.541    0.570      11.8      22.7       0.174
# 4  12.0  21.3   0.185     0.557    0.591      12.1      25.0       0.199
#
# [5 rows x 24 columns]

# %%
#Process stats df 
stats_df['abbr'] = stats_df['Tm'].str.slice(stop=3)
stats_df['Year'] = stats_df['Season'].str.slice(start=5)
stats_df.head()
# Out:
#    Rk   Season    Tm   Lg   G   W   L   W/L%   MOV   SOS  ...  TOV%  ORB%  \
# 0   1  2020-21  WAS*  NBA  72  34  38  0.472 -1.83 -0.01  ...  12.3  21.3
# 1   2  2020-21  UTA*  NBA  72  52  20  0.722  9.25 -0.29  ...  12.7  24.5
# 2   3  2020-21   TOR  NBA  72  27  45  0.375 -0.47 -0.07  ...  11.9  20.8
# 3   4  2020-21   SAS  NBA  72  33  39  0.458 -1.74  0.15  ...  10.2  20.0
# 4   5  2020-21   SAC  NBA  72  31  41  0.431 -3.68  0.23  ...  12.0  21.3
#
#    FT/FGA  opp_eFG%  opp_TS%  opp_TOV%  opp_ORB%  opp_FT/FGA  abbr  Year
# 0   0.221     0.539    0.576      12.5      22.4       0.217   WAS    21
# 1   0.195     0.507    0.537      10.3      20.7       0.159   UTA    21
# 2   0.196     0.543    0.584      14.4      23.7       0.234   TOR    21
# 3   0.192     0.541    0.570      11.8      22.7       0.174   SAS    21
# 4   0.185     0.557    0.591      12.1      25.0       0.199   SAC    21
#
# [5 rows x 26 columns]

# %%
# remove usless columns
stats_df = stats_df.drop(['Rk', 'Season', 'Tm', 'Lg'], axis=1)
stats_df.head()
# Out:
#     G   W   L   W/L%   MOV   SOS   SRS   Pace   ORtg   DRtg  ...  TOV%  ORB%  \
# 0  72  34  38  0.472 -1.83 -0.01 -1.85  104.1  111.2  113.0  ...  12.3  21.3
# 1  72  52  20  0.722  9.25 -0.29  8.97   98.5  117.6  108.3  ...  12.7  24.5
# 2  72  27  45  0.375 -0.47 -0.07 -0.54   99.2  112.0  112.5  ...  11.9  20.8
# 3  72  33  39  0.458 -1.74  0.15 -1.58   98.9  111.0  112.8  ...  10.2  20.0
# 4  72  31  41  0.431 -3.68  0.23 -3.45  100.0  113.6  117.2  ...  12.0  21.3
#
#    FT/FGA  opp_eFG%  opp_TS%  opp_TOV%  opp_ORB%  opp_FT/FGA  abbr  Year
# 0   0.221     0.539    0.576      12.5      22.4       0.217   WAS    21
# 1   0.195     0.507    0.537      10.3      20.7       0.159   UTA    21
# 2   0.196     0.543    0.584      14.4      23.7       0.234   TOR    21
# 3   0.192     0.541    0.570      11.8      22.7       0.174   SAS    21
# 4   0.185     0.557    0.591      12.1      25.0       0.199   SAC    21
#
# [5 rows x 22 columns]

# %%
# Load the champions.csv dataset.
csv_path = Path("champions.csv")
champions_df = pd.read_csv(csv_path)
champions_df
# Out:
#     Year   Lg               Champion              Runner-Up        Finals MVP  \
# 0   2021  NBA        Milwaukee Bucks           Phoenix Suns  G. Antetokounmpo
# 1   2020  NBA     Los Angeles Lakers             Miami Heat          L. James
# 2   2019  NBA        Toronto Raptors  Golden State Warriors        K. Leonard
# 3   2018  NBA  Golden State Warriors    Cleveland Cavaliers         K. Durant
# 4   2017  NBA  Golden State Warriors    Cleveland Cavaliers         K. Durant
# ..   ...  ...                    ...                    ...               ...
# 79  1951  NBA       Rochester Royals        New York Knicks               NaN
# 80  1950  NBA     Minneapolis Lakers     Syracuse Nationals               NaN
# 81  1949  BAA     Minneapolis Lakers    Washington Capitols               NaN
# 82  1948  BAA      Baltimore Bullets  Philadelphia Warriors               NaN
# 83  1947  BAA  Philadelphia Warriors          Chicago Stags               NaN
#
# ...

# %%
#Sort Champions df to only show Champions after 1990
champions_df = champions_df[(champions_df['Year'] > 1990)]
champions_df
# Out:
#     Year   Lg               Champion               Runner-Up  \
# 0   2021  NBA        Milwaukee Bucks            Phoenix Suns
# 1   2020  NBA     Los Angeles Lakers              Miami Heat
# 2   2019  NBA        Toronto Raptors   Golden State Warriors
# 3   2018  NBA  Golden State Warriors     Cleveland Cavaliers
# 4   2017  NBA  Golden State Warriors     Cleveland Cavaliers
# 5   2016  NBA    Cleveland Cavaliers   Golden State Warriors
# 6   2015  NBA  Golden State Warriors     Cleveland Cavaliers
# 7   2014  NBA      San Antonio Spurs              Miami Heat
# 8   2013  NBA             Miami Heat       San Antonio Spurs
# 9   2012  NBA             Miami Heat   Oklahoma City Thunder
# 10  2011  NBA       Dallas Mavericks              Miami Heat
# 11  2010  NBA     Los Angeles Lakers          Boston Celtics
# 12  2009  NBA     Los Angeles Lakers           Orlando Magic
# 13  2008  NBA         Boston Celtics      Los Angeles Lakers
# ...

# %%
# Process champions df
champions_df['teamname'] = champions_df['Champion']
champions_df = champions_df.drop(['Champion','Lg', 'Runner-Up', 'Finals MVP', 'Unnamed: 5', 'Points', 'Rebounds', 'Assists', 'Win Shares'], axis=1)
champions_df
# Out:
# C:\Users\fateh.luqman\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     Year               teamname
# 0   2021        Milwaukee Bucks
# 1   2020     Los Angeles Lakers
# 2   2019        Toronto Raptors
# 3   2018  Golden State Warriors
# 4   2017  Golden State Warriors
# 5   2016    Cleveland Cavaliers
# 6   2015  Golden State Warriors
# 7   2014      San Antonio Spurs
# 8   2013             Miami Heat
# 9   2012             Miami Heat
# 10  2011       Dallas Mavericks
# 11  2010     Los Angeles Lakers
# 12  2009     Los Angeles Lakers
# 13  2008         Boston Celtics
# 14  2007      San Antonio Spurs
# ...

# %%
# Load the team_name.csv dataset.
csv_path = Path("team_name.csv")
team_name_df = pd.read_csv(csv_path)
team_name_df
# Out:
#                   teamname  abbr
# 0            Atlanta Hawks   ATL
# 1           Boston Celtics   BOS
# 2            Brooklyn Nets   BRK
# 3            Chicago Bulls   CHI
# 4        Charlotte Hornets   CHO
# 5      Cleveland Cavaliers   CLE
# 6         Dallas Mavericks   DAL
# 7           Denver Nuggets   DEN
# 8          Detroit Pistons   DET
# 9    Golden State Warriors   GSW
# 10         Houston Rockets   HOU
# 11          Indiana Pacers   IND
# 12    Los Angeles Clippers   LAC
# 13      Los Angeles Lakers   LAL
# 14       Memphis Grizzlies   MEM
# 15              Miami Heat   MIA
# 16         Milwaukee Bucks   MIL
# 17  Minnesota Timberwolves   MIN
# 18    New Orleans Pelicans   NOP
# 19         New York Knicks   NYK
# 20   Oklahoma City Thunder   OKC
# 21           Orlando Magic   ORL
# 22      Philadelphia 76ers   PHI
# 23            Phoenix Suns   PHO
# 24  Portland Trail Blazers   POR
# 25        Sacramento Kings   SAC
# 26       San Antonio Spurs   SAS
# ...

# %%
# Merge Champion teamname with city abbr
champions_df = pd.merge(champions_df, team_name_df, how="inner", on=['teamname'])
champions_df
# Out:
#     Year               teamname abbr
# 0   2021        Milwaukee Bucks  MIL
# 1   2020     Los Angeles Lakers  LAL
# 2   2010     Los Angeles Lakers  LAL
# 3   2009     Los Angeles Lakers  LAL
# 4   2002     Los Angeles Lakers  LAL
# 5   2001     Los Angeles Lakers  LAL
# 6   2000     Los Angeles Lakers  LAL
# 7   2019        Toronto Raptors  TOR
# 8   2018  Golden State Warriors  GSW
# 9   2017  Golden State Warriors  GSW
# 10  2015  Golden State Warriors  GSW
# 11  2016    Cleveland Cavaliers  CLE
# 12  2014      San Antonio Spurs  SAS
# 13  2007      San Antonio Spurs  SAS
# 14  2005      San Antonio Spurs  SAS
# 15  2003      San Antonio Spurs  SAS
# 16  1999      San Antonio Spurs  SAS
# 17  2013             Miami Heat  MIA
# 18  2012             Miami Heat  MIA
# 19  2006             Miami Heat  MIA
# 20  2011       Dallas Mavericks  DAL
# 21  2008         Boston Celtics  BOS
# 22  2004        Detroit Pistons  DET
# 23  1998          Chicago Bulls  CHI
# ...

# %%
champions_df['Year'] = champions_df['Year'].astype(str).str.slice(start=2)
#champions_df = champions_df.drop(['teamname'], axis = 1)
champions_df
# Out:
#    Year               teamname abbr
# 0    21        Milwaukee Bucks  MIL
# 1    20     Los Angeles Lakers  LAL
# 2    10     Los Angeles Lakers  LAL
# 3    09     Los Angeles Lakers  LAL
# 4    02     Los Angeles Lakers  LAL
# 5    01     Los Angeles Lakers  LAL
# 6    00     Los Angeles Lakers  LAL
# 7    19        Toronto Raptors  TOR
# 8    18  Golden State Warriors  GSW
# 9    17  Golden State Warriors  GSW
# 10   15  Golden State Warriors  GSW
# 11   16    Cleveland Cavaliers  CLE
# 12   14      San Antonio Spurs  SAS
# 13   07      San Antonio Spurs  SAS
# 14   05      San Antonio Spurs  SAS
# 15   03      San Antonio Spurs  SAS
# 16   99      San Antonio Spurs  SAS
# 17   13             Miami Heat  MIA
# 18   12             Miami Heat  MIA
# 19   06             Miami Heat  MIA
# 20   11       Dallas Mavericks  DAL
# 21   08         Boston Celtics  BOS
# 22   04        Detroit Pistons  DET
# 23   98          Chicago Bulls  CHI
# 24   97          Chicago Bulls  CHI
# ...

# %%
# merge Champions with thier stats from championship year- (PERFROM ML ON THIS DATA SET)
champ_stats_df = pd.merge(champions_df, stats_df, on=['Year', 'abbr'])
champ_stats_df
# Out:
#    Year               teamname abbr   G   W   L   W/L%    MOV   SOS    SRS  \
# 0    21        Milwaukee Bucks  MIL  72  46  26  0.639   5.89 -0.32   5.57
# 1    20     Los Angeles Lakers  LAL  71  52  19  0.732   5.79  0.49   6.28
# 2    10     Los Angeles Lakers  LAL  82  57  25  0.695   4.72  0.06   4.78
# 3    09     Los Angeles Lakers  LAL  82  65  17  0.793   7.66 -0.55   7.11
# 4    02     Los Angeles Lakers  LAL  82  58  24  0.707   7.12  0.03   7.15
# 5    01     Los Angeles Lakers  LAL  82  56  26  0.683   3.38  0.37   3.74
# 6    00     Los Angeles Lakers  LAL  82  67  15  0.817   8.55 -0.14   8.41
# 7    19        Toronto Raptors  TOR  82  58  24  0.707   6.09 -0.60   5.49
# 8    18  Golden State Warriors  GSW  82  58  24  0.707   5.98 -0.19   5.79
# 9    17  Golden State Warriors  GSW  82  67  15  0.817  11.63 -0.28  11.35
# 10   15  Golden State Warriors  GSW  82  67  15  0.817  10.10 -0.09  10.01
# ...

# %%
# Load the cy_stats.csv dataset.
csv_path = Path("cy_stats.csv")
cy_stats_df = pd.read_csv(csv_path)
cy_stats_df
# Out:
#     Rk   Season   Tm   Lg  G  W  L   W/L%    MOV   SOS  ...   eFG%    TS%  \
# 0    1  2021-22  MIA  NBA  6  5  1  0.833  17.00  1.07  ...  0.525  0.565
# 1    2  2021-22  WAS  NBA  7  5  2  0.714   2.57  1.11  ...  0.505  0.549
# 2    3  2021-22  UTA  NBA  6  5  1  0.833  12.83 -3.08  ...  0.526  0.574
# 3    4  2021-22  TOR  NBA  8  5  3  0.625   4.63  1.25  ...  0.487  0.518
# 4    5  2021-22  SAS  NBA  7  2  5  0.286  -0.43 -1.50  ...  0.526  0.542
# 5    6  2021-22  SAC  NBA  6  3  3  0.500  -2.83 -1.06  ...  0.508  0.543
# 6    7  2021-22  POR  NBA  7  3  4  0.429   1.86 -0.95  ...  0.540  0.565
# 7    8  2021-22  PHO  NBA  5  2  3  0.400  -5.00 -1.64  ...  0.511  0.539
# 8    9  2021-22  PHI  NBA  7  5  2  0.714   8.57 -2.13  ...  0.571  0.607
# 9   10  2021-22  ORL  NBA  8  2  6  0.250  -7.63  3.26  ...  0.518  0.551
# 10  11  2021-22  OKC  NBA  7  1  6  0.143 -13.14  0.10  ...  0.472  0.505
# 11  12  2021-22  NYK  NBA  7  5  2  0.714   4.86  0.52  ...  0.558  0.585
# ...
